# %%
import pandas as pd
from datetime import datetime

# %%
df_data = pd.read_csv("Dados\\CLEAN_FIFA23_official_data.csv", index_col=0)
df_data = df_data.loc[(df_data["Contract Valid Until"] >= datetime.today().year) 
                        & (df_data["Value(£)"] > 0)
                        ]\
                    .sort_values(by='Overall', ascending=False)
df_data
# Out:
#            ID              Name  Age  \
# 75     231747         K. Mbappé   23
# 3      192985      K. De Bruyne   31
# 41     188545    R. Lewandowski   33
# 192    203376       V. van Dijk   30
# 14357  192119       T. Courtois   30
# ...       ...               ...  ...
# 16054  269019         Wu Junjie   19
# 15913  268280  22 L. Hebbelmann   22
# 14880  269130      22 Hu Jiajin   16
# 15513  266751   22 Jung Ho Yeon   20
# 16215  268279    22 J. Looschen   24
#
#                                                   Photo     Nationality  \
# 75     https://cdn.sofifa.net/players/231/747/23_60.png          France
# 3      https://cdn.sofifa.net/players/192/985/23_60.png         Belgium
# 41     https://cdn.sofifa.net/players/188/545/23_60.png          Poland
# 192    https://cdn.sofifa.net/players/203/376/23_60.png     Netherlands
# 14357  https://cdn.sofifa.net/players/192/119/23_60.png         Belgium
# ...                                                 ...             ...
# ...

# %%
stats = df_data.reset_index().iloc(0)
stats['Name']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 stats = df_data.iloc(0)
# ----> 2 stats['Name']
#
# File d:\Drives\OneDrive\LeoRossiniPessoal\Pessoal\Educação\Tecnologia\Python\Azimov\13 Streamlit\venv\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File d:\Drives\OneDrive\LeoRossiniPessoal\Pessoal\Educação\Tecnologia\Python\Azimov\13 Streamlit\venv\Lib\site-packages\pandas\core\indexing.py:1749, in _iLocIndexer._getitem_axis(self, key, axis)
#    1747 key = item_from_zerodim(key)
#    1748 if not is_integer(key):
# ...
